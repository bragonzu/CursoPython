# %%
# librerias en Python para data science
#Pandas 
#Numpy
#SciPy

# %%
#lIBRERIAS EN PYTHON PARA VIZUALIZACION
#MATPLOIT
#SEABORN

# %%
#LIBRERIAS EN PYTHON ALGORITMICAS
#SCIKIT-LEARN
#STATSMODELS

# %%
#import a csv into python
#Libreria para leer
import pandas as pd

#data source:
url="https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data"
urlheader="https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.names"
#Sin encabezado porque no tiene.
data= pd.read_csv(url,header=None)

##imprimir dataframe
#data

#Agregar headers:
headers=["symboling","nomalized-losses","make","fuel-type","aspiration","num-of-doors","body-style","drive-wheels","engine-location","wheel-base","length","width","height","curb-weight","engine-type","num-of-cylinders"," engine-size"," fuel-system","bore","stroke","compression-ratio","horsepower","peak-rpm","city-mpg","highway-mpg","price"]
data.columns=headers

#imprimimos datafram:
data.head(5)


#Tipos para leer y guardar
#csv       pd.read_csv()         df.to_csv()
#json       pd.read_json()       df.to_json()
#excel      pd.read_excel()       df.to_excel()
#sql     pd.read_sql()           df.to_sql()

#GUARDAR  TO CSV
lugar="..\data.csv"
data.to_csv(lugar)

# %%
#Basic insight of datasets
#Pandas                    #python 
#object                    string 
#int64                     int
#float64                   float
#datetime64,timedelta(ns)  N/A

# %%
data.dtypes
# Out:
# symboling              int64
# nomalized-losses      object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
#  engine-size           int64
#  fuel-system          object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
data.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight   engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000    205.000000         205.000000  205.000000   205.000000
# mean   2555.565854    126.907317          10.142537   25.219512    30.751220
# std     520.680204     41.642693           3.972040    6.542142     6.886443
# ...

# %%
data.head(5)
# Out:
#    symboling nomalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                ?  alfa-romero       gas        std          two
# 1          3                ?  alfa-romero       gas        std          two
# 2          1                ?  alfa-romero       gas        std          two
# 3          2              164         audi       gas        std         four
# 4          2              164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...   engine-size  \
# 0  convertible          rwd           front        88.6  ...           130
# 1  convertible          rwd           front        88.6  ...           130
# 2    hatchback          rwd           front        94.5  ...           152
# 3        sedan          fwd           front        99.8  ...           109
# 4        sedan          4wd           front        99.4  ...           136
#
# ...

# %%
data.describe(include="all")
# Out:
#          symboling nomalized-losses    make fuel-type aspiration num-of-doors  \
# count   205.000000              205     205       205        205          205
# unique         NaN               52      22         2          2            3
# top            NaN                ?  toyota       gas        std         four
# freq           NaN               41      32       185        168          114
# mean      0.834146              NaN     NaN       NaN        NaN          NaN
# std       1.245307              NaN     NaN       NaN        NaN          NaN
# min      -2.000000              NaN     NaN       NaN        NaN          NaN
# 25%       0.000000              NaN     NaN       NaN        NaN          NaN
# 50%       1.000000              NaN     NaN       NaN        NaN          NaN
# 75%       2.000000              NaN     NaN       NaN        NaN          NaN
# max       3.000000              NaN     NaN       NaN        NaN          NaN
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   nomalized-losses   205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
#Data Pre-procesing

data["symboling"]=data["symboling"]+1

# %%
#drop missing values in python
#data.dropna()
#data.dropna(subset=["price"],axis=0)
#data.dropna(subset=["price"],axis=0,inplace=True)

# %%
#replace misssing values in Python
#dataframe.replace(missing_values,new_value)
mean=data["nomalized-losses"].mean()
data["nomalized-losses"].replace(np.nan,mean)

# %%
#Data Formatting
data["city-mpg"]=235/data["city-mpg"]
data.rename(columns={"city_mpg": "city-L/100km"}, inplace=True)

# %%
#cORRECTING DATA TYPES
#IDENTIFICAR  
dataframe.dtypes()
#convertir
dataframe.astype()
# Out:
# 200    16845
# 201    19045
# 202    21485
# 203    22470
# 204    22625
# Name: price, dtype: object

# %%
#METHOD OF NORMALIING DATA
#SIMPLE FEATURE SCALIN IN PYTHON CON PANDAS
data["length"]=data["length"]/data["length"].max()
#MIN-MAX IN PYTHON CON PANDAS
data["length"]=(data["length"]-data["length"].min())/(data["length"].max()-data["length"].min())
#Z-score in python
data["length"]=(data["length"]-data["length"].mean())/data["length"].std( )

# %%
#Binning
bins=np.linspace(min(data["price"]),max(data["price"]),4)
group_names=["low","medium","high"]
data["price-binned"]=pd.cut(data["price"]),bin,labels=group_names,include_lowest=True)

# %%
#Categorical -> Numeric
pd.get_dummies(data["fuel"])

# %%
#Value_counts
drive_wheels_counts=df["drive-wheels"].value_counts()
drive_wheels_counts.rename(columns={'drive-wheels': 'value_counts',inplace=True)
drive_wheels_counts.index.name='drive-wheels'

# %%
#Scatter Plot
y= data[engine-size]
x=data["price"]
plt.title("Scatterplot of engine size vs price")
plt.xlabel("Engine Size")
plt.x label("Price")

# %%
#GroupBy
dt_test= data[['drive-wheels', 'body-style', 'price']]
dt_grp= dt_test.groupby(['drive-wheels','body-style'], asindex=False).mean()
dt_grp

# %%
#Pivot
dt_pivot=data_grp.pivot(index='drive-wheels',columns='body-stye')

# %%
#Heatmap
plt.pcolor(dt_pivot,cmap='RdBu')
plt.colorbar()
plt.show()

# %%
#Analysis de Varianza
df_Anova=data[{"make","price"}]
grouped_anova=df_anova-groupby(["make"])

# %%
#Correlation positive Linear Relationship
sns.regplot(x="engin-size",y="prices", data=df)
Plt.ylim(0,)

# %%
#Correlation - Statics
#2features: Correlation coefficient , P-value
#Correlation coefficient             #P-value
#Close to +1                         P-value<0.001
#Close to -1                        P-value<0.05
#Close to +1                        P-value<0.1
#                                   P-value>0.1

#strong correlation:
#correlation coefficient close to 1 or -1
#p value less than 0.001


#Pearson correlation
Pearson_coef,p_value=stats.personr[['horsepower'],df['price']]

pearson correlation 0.81
p- value=

# %%
#Model Development
#Linear regression
#Simple linear regresion

# %%
#fitting a simplelinear model estimator
#import linear model from scikit learn
from sklearn.linear_model import LinearRegression
#create alinear regresion object using the constructor
lm=LinearReegression()

# %%
#fitting a multiplelinear model estimator
#we can extract the for 4 predictor variables and store them in the variable z
z= df[['horsepower'.'curb-weight','engine-size','highway-mpg']]

#THEN TRAIN THE MODEL AS BEFORE:
lm.fit(Z,df['price'])
#We can also obtain a prediction
Yhat= lm.predict(X)

# %%
#Model Evaluation using visualization
#Regression plot.
import seaborn as  sns
sns.regplot(x="highway-mpg",y="price",data=df)
plt.ylim(0,)

# %%
#Resigual Plot
import seaborn as sns
sns.residplot(df['highway-mpg'],df['price'])

# %%
#Distribution Plots
import seaborn as sns
ax1=sns.distplot(df['price'],hist=False, color="r",label="Actual Value")
sns.distplot(Yhat,hist= False , color="b",label="Fitted Values", ax=ax1)

# %%
#Polynomial regresion and pipelines 
#https://prnt.sc/zy53hv
#Calculate polynomial of 3rd order
f=np.polyfit(x,y,3)
p=no.polyld(f)
#we can print out the model
print(p)

# %%
#preprocessing
from sklearn.preprocessing import Standardcaler
SCALE=StandarScaler()
SCALE.fit(x_data[['horsepower', 'highway-mpg']])
x_scale= SCALE.transform(x_data[['horsepower', 'highway-mpg']])

#pipeline    -https://prnt.sc/zy5pl0
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandarScaler
from sklearn.pipeline import Pipeline

Input[('scale',StandarScaler()),('polynomial',PolynomialFeatures(degree=2)),('model',LinearRegression())]
#We can train the pipeline object
Pipe.train(X['horsepower','curb-weight','engine-size','high-mpg'],y)
yhat=Pipe.predict(X[['horsepower','curb-weight','engine-size','highway-mpg']])

# %%
#Mean SQUARED error(MSE)
from skearln.metrics import mean_squared_error

# %%
#Prediction and Decision Making
#First we train the model
lm.fit(df.['highway-mpg'],['prices'])
#let's predict the price of a car with 30 hihgway-mpg
lm.predict(30)
lm.coef_

# %%
#Do the predict values make sense
#first we import numpy
import numpy as np
#We use the numpy function arrange to generate a sequence from 1 to 100
new_input=np.arange(1,101,1).reshape(-1,1)

# %%
#-----------------#_----------
#Evaluacion del modelo
#training set 70%
#ttrain 30%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_data,y_data,test_size=0.3,random_state=0)
#https://prnt.sc/10080j5

#Function cross_val_Score()
from sklearn.model_selection import cross_val_score
scores= cross_val_score(lr,_data,y_data,cv=3)

#Has a similar interface to cross_val_score()
from sklearn.model_selection import cross_val_score
yhat=cross_val(predict(lr2e,x_data,y_data,cv=3))

# %%
#Model Selection,overfitting, underfitting
Rsqu_test=[]
order=[1,2,3,4]
for n in order:
    pr=PolynomialFeatures(degree=n)
    x_train_pr=pr.fit_transformation(x_train[['horsepower']])
    x_test_pr=pr.fit_transformation(x_test[['horsepower']])
    lr.fit(x_train_pr,y_train)
    Rsqu_test.append(lr.score(x_test_pr,y_test))
